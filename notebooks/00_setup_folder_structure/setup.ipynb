# %%
import os

# %%
os.makedirs("../../data/original/lending-club", exist_ok=True)
os.makedirs("../../data/original/lt-vehicle-loan-default-prediction", exist_ok=True)
os.makedirs("../../data/processed", exist_ok=True)
os.makedirs("../../models", exist_ok=True)
os.makedirs("../../output/plots/eda/lc", exist_ok=True)
os.makedirs("../../output/plots/eda/lt", exist_ok=True)
os.makedirs("../../output/plots/training/lc", exist_ok=True)
os.makedirs("../../output/plots/training/lt", exist_ok=True)
os.makedirs("../../output/tables/eda", exist_ok=True)
